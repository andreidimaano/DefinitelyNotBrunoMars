# %%
from train import MaskCycleGANVCTraining
from mask_test import MaskCycleGANVCTesting as m1
from mask_test2 import MaskCycleGANVCTesting as m2
import pickle
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
def loadPickleFile(fileName):
    """Loads a Pickle file.

    Args:
        fileName (str): pickle file path

    Returns:
        file object: The loaded pickle file object
    """
    with open(fileName, 'rb') as f:
        return pickle.load(f)
    
def get_top_3_indices(arr):
    indices = np.argsort(arr)[:3]
    return indices

def plot_loss(load_id):
    data = pd.read_csv(f'outputs/loss_csv/{load_id}.csv')

    gloss= data['Generator Loss']
    dloss = data['Discriminator Loss']

    plt.plot(gloss, label="gloss")
    plt.plot(dloss, label="dloss")
    plt.title('Loss over Training')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
timeList = [0.9,1.1,1.2]
pitchList = [-2,-1,1,2]
noiseList = [0.1,0.2,0.3]
timePitchList= ['0.9-2', '0.9-1', '0.91', '0.92', '1.1-2', '1.1-1', '1.11', '1.12', '1.2-2', '1.2-1', '1.21', '1.22']

# %%
# mcdsFM = [0] * 8
# glossesFM = [0] * 8
# dlossesFM = [0] * 8
glossesFM = [2.2283271479766795, 2.207811973689341, 2.380725363283749, 2.278054367819524, 2.168506850260415, 0.31281769275665283, 0.23123151063919067, 0]
dlossesFM = [2.2283271479766795, 0.21292302012443542, 0.3295247554779053, 0.31994837522506714, 0.4232684373855591, 0, 0, 0]
mcdsFM = [46.079803, 45.794754, 45.54554, 45.51956, 46.53347, 47.059517, 46.192196, 0]

# %% [markdown]
# ### Train 8 Augment types on Original Dataset
# 1. None
# 2. Time stretch timestretch
# 3. Pitch Shift pitchshift
# 4. Harmonic Distortion harmdist
# 5. White Noise noise
# 6. Frequency Mask freqmask=true
# 7. Time Stretch + Pitch Shift timepitch
# 8. Time Stretch + Freq Mask

# %% [markdown]
# #### VCC2SF3 => VCC2TM1

# %%
# # no augments
# train_id = 0
# speakerA = "VCC2SF3"
# speakerB = "VCC2TM1"
# cycleGAN = MaskCycleGANVCTraining(
#     speakerA=speakerA,
#     speakerB=speakerB,
#     datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
#     datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
#     train_id=train_id,
#     num_epochs=0
#     # num_epochs=130,
#     freq_mask=False,
#     augment_type=None,
#     aug_list=None,
#     load_id=None,
#     load_model=False
#     )
# loss0 = cycleGAN.train()
# glossesFM[0] = loss0[0][-1]
# dlossesFM[0] = loss0[0][-1]
# print(cycleGAN.get_training_time())
# Out:
# n_samples = 81
# generator_lr_decay = 9.49667616334283e-10
# discriminator_lr_decay = 9.496676163342831e-09
# 100%|██████████| 81/81 [00:33<00:00,  2.44it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.85it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.78it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.78it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.76it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.78it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.78it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.78it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.85it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# (3871.7536940574646, 30.013594527577244)

# %%
plot_loss(0)

# %%
load_id = 0
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
test = m2(speakerA, speakerB, load_id)
mcds0 = test.test()
mcdsFM[0] = np.mean(mcds0)
# Out:
# 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]

# %%
# # time stretch
# train_id = 1
# speakerA = "VCC2SF3"
# speakerB = "VCC2TM1"
# cycleGAN = MaskCycleGANVCTraining(
#     speakerA=speakerA,
#     speakerB=speakerB,
#     datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
#     datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
#     train_id=train_id,
#     num_epochs=130,
#     freq_mask=False,
#     augment_type="timestretch",
#     aug_list=timeList,
#     load_id=None,
#     load_model=False
#     )
# loss1 = cycleGAN.train()
# glossesFM[1] = loss1[0][-1]
# dlossesFM[1] = loss1[1][-1]
# print(cycleGAN.get_training_time())
# Out:
# n_samples = 81
# generator_lr_decay = 9.49667616334283e-10
# discriminator_lr_decay = 9.496676163342831e-09
# 100%|██████████| 81/81 [00:27<00:00,  2.98it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.98it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.96it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.96it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.98it/s]
# (3738.2680163383484, 28.97882183208022)

# %%
plot_loss(1)

# %%
load_id = 1
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
test = m2(speakerA, speakerB, load_id)
mcds1 = test.test()
mcdsFM[1] = np.mean(mcds1)
# Out:
# 100%|██████████| 10/10 [00:23<00:00,  2.35s/it]

# %%
# # pitch shift
# train_id = 2
# speakerA = "VCC2SF3"
# speakerB = "VCC2TM1"
# cycleGAN = MaskCycleGANVCTraining(
#     speakerA=speakerA,
#     speakerB=speakerB,
#     datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
#     datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
#     train_id=train_id,
#     num_epochs=130,
#     freq_mask=False,
#     augment_type="pitchshift",
#     aug_list=pitchList,
#     load_id=None,
#     load_model=False
#     )
# loss2 = cycleGAN.train()
# glossesFM[2] = loss2[0][-1]
# dlossesFM[2] = loss2[1][-1]
# print(cycleGAN.get_training_time())
# Out:
# n_samples = 81
# generator_lr_decay = 9.49667616334283e-10
# discriminator_lr_decay = 9.496676163342831e-09
# 100%|██████████| 81/81 [00:27<00:00,  2.98it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.98it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.95it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.75it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.86it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.86it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.86it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.86it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.86it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.86it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.87it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.75it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.94it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# (3766.0048627853394, 29.193836145622786)

# %%
plot_loss(2)

# %%
load_id = 2
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
test = m2(speakerA, speakerB, load_id)
mcds2 = test.test()
mcdsFM[2] = np.mean(mcds2)
# Out:
# Directory 'outputs/generated_audio/2' created successfully.
# 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]

# %%
# # pitch shift
# train_id = 3
# speakerA = "VCC2SF3"
# speakerB = "VCC2TM1"
# cycleGAN = MaskCycleGANVCTraining(
#     speakerA=speakerA,
#     speakerB=speakerB,
#     datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
#     datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
#     train_id=train_id,
#     num_epochs=130,
#     freq_mask=False,
#     augment_type="harmdist",
#     aug_list=None,
#     load_id=None,
#     load_model=False
#     )
# loss3 = cycleGAN.train()
# glossesFM[3] = loss3[0][-1]
# dlossesFM[3] = loss3[1][-1]
# print(cycleGAN.get_training_time())
# Out:
# n_samples = 81
# generator_lr_decay = 9.49667616334283e-10
# discriminator_lr_decay = 9.496676163342831e-09
# 100%|██████████| 81/81 [01:46<00:00,  1.32s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:47<00:00,  1.33s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:46<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:46<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.30s/it]
# 100%|██████████| 81/81 [01:45<00:00,  1.31s/it]
# 100%|██████████| 81/81 [01:39<00:00,  1.23s/it]
# 100%|██████████| 81/81 [01:39<00:00,  1.23s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:40<00:00,  1.24s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.35s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# 100%|██████████| 81/81 [01:48<00:00,  1.34s/it]
# (14081.362901449203, 109.15785194921864)

# %%
plot_loss(3)

# %%
load_id = 3
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
test = m2(speakerA, speakerB, load_id)
mcds3 = test.test()
mcdsFM[3] = np.mean(mcds3)
# Out:
# Directory 'outputs/generated_audio/3' created successfully.
# 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]

# %%
# # white noise
# train_id = 4
# speakerA = "VCC2SF3"
# speakerB = "VCC2TM1"
# cycleGAN = MaskCycleGANVCTraining(
#     speakerA=speakerA,
#     speakerB=speakerB,
#     datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
#     datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
#     train_id=train_id,
#     num_epochs=130,
#     freq_mask=False,
#     augment_type="noise",
#     aug_list=noiseList,
#     load_id=None,
#     load_model=False
#     )
# loss4 = cycleGAN.train()
# glossesFM[4] = loss4[0][-1]
# dlossesFM[4] = loss4[1][-1]
# print(cycleGAN.get_training_time())
# Out:
# n_samples = 81
# generator_lr_decay = 9.49667616334283e-10
# discriminator_lr_decay = 9.496676163342831e-09
# 100%|██████████| 81/81 [01:54<00:00,  1.42s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.42s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.42s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:55<00:00,  1.42s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:55<00:00,  1.42s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.42s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.42s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:54<00:00,  1.41s/it]
# 100%|██████████| 81/81 [01:55<00:00,  1.42s/it]
# 100%|██████████| 81/81 [01:30<00:00,  1.12s/it]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.84it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.85it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# (13697.485897541046, 106.18206122124842)

# %%
plot_loss(4)

# %%
load_id = 4
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
test = m2(speakerA, speakerB, load_id)
mcds4 = test.test()
mcdsFM[4] = np.mean(mcds4)
# Out:
# Directory 'outputs/generated_audio/4' created successfully.
# 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]

# %%
# # pitch shift
# train_id = 5
# speakerA = "VCC2SF3"
# speakerB = "VCC2TM1"
# cycleGAN = MaskCycleGANVCTraining(
#     speakerA=speakerA,
#     speakerB=speakerB,
#     datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
#     datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
#     train_id=train_id,
#     num_epochs=130,
#     freq_mask=True,
#     augment_type=None,
#     aug_list=None,
#     load_id=None,
#     load_model=False
#     )
# loss5 = cycleGAN.train()
# glossesFM[5] = loss5[0][-1]
# glossesFM[5] = loss5[1][-1]
# print(cycleGAN.get_training_time())
# Out:
# n_samples = 81
# generator_lr_decay = 9.49667616334283e-10
# discriminator_lr_decay = 9.496676163342831e-09
# 100%|██████████| 81/81 [00:27<00:00,  2.99it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.93it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.88it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.89it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.91it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.90it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.86it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.72it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.71it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.76it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.75it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.76it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.74it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.76it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.70it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.75it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.73it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.71it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:30<00:00,  2.67it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.76it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.78it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.77it/s]
# 100%|██████████| 81/81 [00:30<00:00,  2.70it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.85it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.02it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.03it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.03it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.03it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.02it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.03it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.07it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.04it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.07it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.07it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.05it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.06it/s]
# (3732.9850327968597, 28.937868471293488)

# %%
plot_loss(5)

# %%
load_id = 5
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
test = m2(speakerA, speakerB, load_id)
mcds5 = test.test()
mcdsFM[5] = np.mean(mcds5)
# Out:
# Directory 'outputs/generated_audio/5' created successfully.
# 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]

# %%
# # Time stretch Pitch Shift
# train_id = 6
# speakerA = "VCC2SF3"
# speakerB = "VCC2TM1"
# cycleGAN = MaskCycleGANVCTraining(
#     speakerA=speakerA,
#     speakerB=speakerB,
#     datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
#     datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
#     train_id=train_id,
#     num_epochs=130,
#     freq_mask=False,
#     augment_type="timepitch",
#     aug_list=timePitchList,
#     load_id=None,
#     load_model=False
#     )
# loss6 = cycleGAN.train()
# glossesFM[6] = loss6[0][-1]
# glossesFM[6] = loss6[1][-1]
# print(cycleGAN.get_training_time())
# Out:
# n_samples = 81
# generator_lr_decay = 9.49667616334283e-10
# discriminator_lr_decay = 9.496676163342831e-09
# 100%|██████████| 81/81 [00:25<00:00,  3.21it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.07it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.14it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.12it/s]
# 100%|██████████| 81/81 [00:25<00:00,  3.13it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.11it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.09it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.07it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.10it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.08it/s]
# 100%|██████████| 81/81 [00:26<00:00,  3.07it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.71it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.76it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.70it/s]
# 100%|██████████| 81/81 [00:27<00:00,  2.92it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.82it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:29<00:00,  2.79it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.81it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.83it/s]
# 100%|██████████| 81/81 [00:28<00:00,  2.80it/s]
# (3551.878158569336, 27.533939213715783)

# %%
plot_loss(6)

# %%
load_id = 6
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
test = m2(speakerA, speakerB, load_id)
mcds6 = test.test()
mcdsFM[6] = np.mean(mcds6)
# Out:
# Directory 'outputs/generated_audio/6' created successfully.
# 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]

# %%
# Time stretch Pitch Shift
train_id = 7
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=True,
    augment_type="timestretch",
    aug_list=timeList,
    load_id=None,
    load_model=False
    )
loss7 = cycleGAN.train()
glossesFM[7] = loss7[0][-1]
dlossesFM[7] = loss7[1][-1]
print(cycleGAN.get_training_time())
# Out:
# n_samples = 81
# generator_lr_decay = 9.49667616334283e-10
# discriminator_lr_decay = 9.496676163342831e-09
#  32%|███▏      | 26/81 [00:09<00:19,  2.83it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 18
#       4 speakerB = "VCC2TM1"
#       5 cycleGAN = MaskCycleGANVCTraining(
#       6     speakerA=speakerA,
#       7     speakerB=speakerB,
#    (...)
#      16     load_model=False
#      17     )
# ---> 18 loss7 = cycleGAN.train()
#      19 glossesFM[7] = loss7[0][-1]
#      20 dlossesFM[7] = loss7[1][-1]
#
# File d:\code\DefinitelyNotBrunoMars\code\train.py:209, in MaskCycleGANVCTraining.train(self)
#     207 for i, (real_A, mask_A, real_B, mask_B) in enumerate(tqdm(self.train_dataloader)):
#     208     with torch.set_grad_enabled(True):
# --> 209         real_A = real_A.to(self.device, dtype=torch.float)
#     210         mask_A = mask_A.to(self.device, dtype=torch.float)
#     211         real_B = real_B.to(self.device, dtype=torch.float)
#
# KeyboardInterrupt:

# %%
load_id = 7
speakerA = "VCC2SF3"
speakerB = "VCC2TM1"
test = m2(speakerA, speakerB, load_id)
mcds7 = test.test()
mcdsFM[7] = np.mean(mcds7)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 4
#       2 speakerA = "VCC2SF3"
#       3 speakerB = "VCC2TM1"
# ----> 4 test = m2(speakerA, speakerB, load_id)
#       5 mcds7 = test.test()
#       6 mcdsFM[7] = np.mean(mcds7)
#
# File d:\code\DefinitelyNotBrunoMars\code\mask_test2.py:22, in MaskCycleGANVCTesting.__init__(self, a_prefix, b_prefix, load_id)
#      20 self.device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
#      21 self.generator = Generator().to(self.device)
# ---> 22 self.generator.load_state_dict(torch.load(f'model_checkpoint/{load_id}/GA2B.pth'))
#      25 self.dataset_A = self.loadPickleFile(f'data/testing_data/{a_prefix}_test_spec.pickle')
#      26 dataset_A_norm_stats = np.load(f'data/testing_data/{a_prefix}_test_norm_stat.npz')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\serialization.py:791, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     788 if 'encoding' not in pickle_load_args.keys():
#     789     pickle_load_args['encoding'] = 'utf-8'
# --> 791 with _open_file_like(f, 'rb') as opened_file:
#     792     if _is_zipfile(opened_file):
#     793         # The zipfile reader is going to advance the current file position.
#     794         # If we want to actually tail call to torch.jit.load, we need to
#     795         # reset back to the original position.
#     796         orig_position = opened_file.tell()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\serialization.py:271, in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\serialization.py:252, in _open_file.__init__(self, name, mode)
#     251 def __init__(self, name, mode):
# --> 252     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_checkpoint/7/GA2B.pth'

# %%
augment_names = ["None", "Time Stretch", "Pitch Shift", "Harmonic Distortion", "White Noise", "Frequency Mask", "Time Stretch and Pitch Shift", "Time Stretch and Frequency Mask"]
augments = [None, "timestretch", "pitchshift", "harmdist", "noise", None, "timepitch", "timestretch"]
freqmasks = [False, False, False, False, False, True, False, True]
auglists = [None, timeList, pitchList, None, None, None,timePitchList,timeList]

# %%
print(glossesFM)
print(dlossesFM)
print(mcdsFM)
# Out:
# [2.2283271479766795, 2.207811973689341, 2.380725363283749, 2.278054367819524, 2.168506850260415, 0.31281769275665283, 0.23123151063919067, 0]
# [2.2283271479766795, 0.21292302012443542, 0.3295247554779053, 0.31994837522506714, 0.4232684373855591, 0, 0, 0]
# [46.079803, 45.794754, 45.54554, 45.51956, 46.53347, 47.059517, 46.192196, 0]

# %%
fm_top = get_top_3_indices(mcdsFM)
mcdsV1 = [0] * 3
glossesV1 = [0] * 3
dlossesV1 = [0] * 3

# %%
#FM 1
train_id = 16
speakerA = "iu"
speakerB = "bruno_mars"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=3,
    freq_mask=freqmasks[fm_top[0]],
    augment_type=augments[fm_top[0]],
    aug_list=auglists[fm_top[0]],
    load_id=None,
    load_model=False
    )
loss0 = cycleGAN.train()
glossesV1[0] = loss0[0][-1]
dlossesV1[0] = loss0[1][-1]
print(cycleGAN.get_training_time())
# Out:
# n_samples = 10
# generator_lr_decay = 3.3333333333333335e-07
# discriminator_lr_decay = 3.3333333333333333e-06
# 100%|██████████| 10/10 [00:03<00:00,  2.98it/s]
# 100%|██████████| 10/10 [00:03<00:00,  2.98it/s]
# 100%|██████████| 10/10 [00:03<00:00,  2.98it/s]
# (12.888031721115112, 6.444015860557556)

# %%
load_id = 16
speakerA = "iu"
speakerB = "bruno_mars"
test = m1(speakerA, speakerB, load_id)
mcds0 = test.test()
mcdsV1[0] = np.mean(mcds0)
# Out:
# Directory 'outputs/generated_audio/16' created successfully.
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 5
#       3 speakerB = "bruno_mars"
#       4 test = m1(speakerA, speakerB, load_id)
# ----> 5 mcds0 = test.test()
#       6 mcdsV1[0] = np.mean(mcds0)
#
# File d:\code\DefinitelyNotBrunoMars\code\mask_test.py:72, in MaskCycleGANVCTesting.test(self)
#      70     print(f"Directory '{directory_path}' created successfully.")
#      71 mcds = list()
# ---> 72 for i, sample in enumerate(tqdm(self.test_dataloader)):
#      73     # converts full if small sample else 10 second sample
#      74     real_A = sample[:,:,2616:2616+872]
#      75     real_A = real_A.to(self.device, dtype=torch.float)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tqdm\std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
#    1181         # Note: does not call self.update(1) for speed optimisation.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File d:\code\DefinitelyNotBrunoMars\code\data\VCDataset.py:31, in VCDataset.__getitem__(self, index)
#      29 def __getitem__(self, index):
#      30     datasetA_spec = self.datasetA_spec.copy()
# ---> 31     datasetB_spec = self.datasetB_spec.copy()
#      32     n_frames = self.n_frames # where each training sample consisted of 64 randomly cropped frames
#      33     if self.valid:
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
#FM 2
train_id = 17
speakerA = "iu"
speakerB = "bruno_mars"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=1500,
    freq_mask=freqmasks[fm_top[1]],
    augment_type=augments[fm_top[1]],
    aug_list=auglists[fm_top[1]],
    load_id=None,
    load_model=False
    )
loss0 = cycleGAN.train()
glossesV1[1] = loss0[0][-1]
dlossesV1[1] = loss0[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 17
speakerA = "iu"
speakerB = "bruno_mars"
test = m1(speakerA, speakerB, load_id)
mcds1 = test.test()
mcdsV1[1] = np.mean(mcds1)

# %%
#FM 3
train_id = 18
speakerA = "iu"
speakerB = "bruno_mars"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=1500,
    freq_mask=freqmasks[fm_top[2]],
    augment_type=augments[fm_top[2]],
    aug_list=auglists[fm_top[2]],
    load_id=None,
    load_model=False
    )
loss0 = cycleGAN.train()
glossesV1[2] = loss0[0][-1]
dlossesV1[2] = loss0[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 18
speakerA = "iu"
speakerB = "bruno_mars"
test = m1(speakerA, speakerB, load_id)
mcds1 = test.test()
mcdsV1[2] = np.mean(mcds1)

# %% [markdown]
# ### VCC2M3 => VCCTF1

# %%
mcdsMF = [0] * 8
glossesMF = [0] * 8
dlossesMF = [0] * 8

# %%
# no augments
train_id = 8
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=False,
    augment_type=None,
    aug_list=None,
    load_id=None,
    load_model=False
    )
loss0 = cycleGAN.train()
glossesMF[0] = loss0[0][-1]
dlossesMF[0] = loss0[0][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 8
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
test = m2(speakerA, speakerB, load_id)
mcds0 = test.test()
mcdsMF[0] = np.mean(mcds0)

# %%
# time stretch
train_id = 9
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=False,
    augment_type="timestretch",
    aug_list=timeList,
    load_id=None,
    load_model=False
    )
loss1 = cycleGAN.train()
glossesMF[1] = loss1[0][-1]
dlossesMF[1] = loss1[0][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 9
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
test = m2(speakerA, speakerB, load_id)
mcds1 = test.test()
mcdsMF[1] = np.mean(mcds1)

# %%
# pitch shift
train_id = 10
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=False,
    augment_type="pitchshift",
    aug_list=pitchList,
    load_id=None,
    load_model=False
    )
loss2 = cycleGAN.train()
glossesMF[2] = loss2[0][-1]
dlossesMF[2] = loss2[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 10
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
test = m2(speakerA, speakerB, load_id)
mcds2 = test.test()
mcdsMF[2] = np.mean(mcds1)

# %%
train_id = 11
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=False,
    augment_type="harmdist",
    aug_list=None,
    load_id=None,
    load_model=False
    )
loss3 = cycleGAN.train()
glossesMF[3] = loss3[0][-1]
dlossesMF[3] = loss3[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 11
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
test = m2(speakerA, speakerB, load_id)
mcds3 = test.test()
mcdsMF[3] = np.mean(mcds3)

# %%
# pitch shift
train_id = 12
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=False,
    augment_type="noise",
    aug_list=noiseList,
    load_id=None,
    load_model=False
    )
loss4 = cycleGAN.train()
glossesMF[4] = loss4[0][-1]
dlossesMF[4] = loss4[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 12
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
test = m2(speakerA, speakerB, load_id)
mcds4 = test.test()
mcdsMF[4] = np.mean(mcds4)

# %%
# pitch shift
train_id = 13
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=True,
    augment_type=None,
    aug_list=None,
    load_id=None,
    load_model=False
    )
loss5 = cycleGAN.train()
glossesFM[5] = loss5[0][-1]
glossesFM[5] = loss5[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 13
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
test = m2(speakerA, speakerB, load_id)
mcds5 = test.test()
mcdsMF[5] = np.mean(mcds5)

# %%
# Time stretch Pitch Shift
train_id = 14
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=False,
    augment_type="timepitch",
    aug_list=timePitchList,
    load_id=None,
    load_model=False
    )
loss6 = cycleGAN.train()
glossesMF[6] = loss6[0][-1]
glossesMF[6] = loss6[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 14
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
test = m2(speakerA, speakerB, load_id)
mcds6 = test.test()
mcdsMF[6] = np.mean(mcds6)

# %%
# Time stretch Pitch Shift
train_id = 15
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=130,
    freq_mask=True,
    augment_type="timestretch",
    aug_list=timeList,
    load_id=None,
    load_model=False
    )
loss7 = cycleGAN.train()
glossesMF[7] = loss7[0][-1]
dlossesMF[7] = loss7[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 15
speakerA = "VCC2SM3"
speakerB = "VCC2TF1"
test = m2(speakerA, speakerB, load_id)
mcds7 = test.test()
mcdsMF[7] = np.mean(mcds7)

# %%
mf_top = get_top_3_indices(mcdsMF)
mcdsV2 = [0] * 3
glossesV2 = [0] * 3
dlossesV2 = [0] * 3

# %%
#MF 1
train_id = 19
speakerA = "bruno_mars"
speakerB = "iu"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=1500,
    freq_mask=freqmasks[mf_top[0]],
    augment_type=augments[mf_top[0]],
    aug_list=auglists[mf_top[0]],
    load_id=None,
    load_model=False
    )
loss0 = cycleGAN.train()
glossesV2[0] = loss0[0][-1]
dlossesV2[0] = loss0[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 19
speakerA = "bruno_mars"
speakerB = "iu"
test = m1(speakerA, speakerB, load_id)
mcds1 = test.test()
mcdsV2[0] = np.mean(mcds1)

# %%
#MF 2
train_id = 20
speakerA = "bruno_mars"
speakerB = "iu"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=1500,
    freq_mask=freqmasks[mf_top[1]],
    augment_type=augments[mf_top[1]],
    aug_list=auglists[mf_top[1]],
    load_id=None,
    load_model=False
    )
loss0 = cycleGAN.train()
glossesV2[1] = loss0[0][-1]
dlossesV2[1] = loss0[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 20
speakerA = "bruno_mars"
speakerB = "iu"
test = m1(speakerA, speakerB, load_id)
mcds1 = test.test()
mcdsV2[1] = np.mean(mcds1)

# %%
#MF 3
train_id = 21
speakerA = "bruno_mars"
speakerB = "iu"
cycleGAN = MaskCycleGANVCTraining(
    speakerA=speakerA,
    speakerB=speakerB,
    datasetA_spec=loadPickleFile(f'data/training_data/{speakerA}_train_spec.pickle'),
    datasetB_spec=loadPickleFile(f'data/training_data/{speakerB}_train_spec.pickle'),
    train_id=train_id,
    num_epochs=1500,
    freq_mask=freqmasks[mf_top[2]],
    augment_type=augments[mf_top[2]],
    aug_list=auglists[mf_top[2]],
    load_id=None,
    load_model=False
    )
loss0 = cycleGAN.train()
glossesV2[2] = loss0[0][-1]
dlossesV2[2] = loss0[1][-1]
print(cycleGAN.get_training_time())

# %%
load_id = 21
speakerA = "bruno_mars"
speakerB = "iu"
test = m1(speakerA, speakerB, load_id)
mcds2 = test.test()
mcdsV2[2] = np.mean(mcds2)
